# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

# %%
json = pd.read_json('C:/Users/Owner/Documents/data_science/1574117884_data_wrangling_json_5_/data_wrangling_json/data/world_bank_projects.json')
json.head(2)
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
#
#             closingdate                              country_namecode  \
# 0  2018-07-07T00:00:00Z  Federal Democratic Republic of Ethiopia!$!ET
# 1                   NaN                      Republic of Tunisia!$!TN
#
#   countrycode                              countryname countryshortname  ...  \
# 0          ET  Federal Democratic Republic of Ethiopia         Ethiopia  ...
# 1          TN                      Republic of Tunisia          Tunisia  ...
#
#     sectorcode source  status  supplementprojectflg  \
# ...

# %%
#Import of json file with json.load
import json

with open('C:/Users/Owner/Documents/data_science/1574117884_data_wrangling_json_5_/data_wrangling_json/data/World_Bank_projects_less.json') as f:
    data = json.load(f)

# %%
#Normalized table of json data using json_normalize

import pandas as pd 
import json
from pandas.io.json import json_normalize

data= json.load((open('C:/Users/Owner/Documents/data_science/1574117884_data_wrangling_json_5_/data_wrangling_json/data/World_Bank_projects.json')))
normalized_data = json_normalize(data)

# %%
#10 top countries with highest submission of projects

df = pd.read_json('C:/Users/Owner/Documents/data_science/1574117884_data_wrangling_json_5_/data_wrangling_json/data/world_bank_projects.json')
df_top_freq = df['country_namecode'].value_counts()
print(df_top_freq.head(10))
# Out:
# Republic of Indonesia!$!ID              19
# People's Republic of China!$!CN         19
# Socialist Republic of Vietnam!$!VN      17
# Republic of India!$!IN                  16
# Republic of Yemen!$!RY                  13
# People's Republic of Bangladesh!$!BD    12
# Kingdom of Morocco!$!MA                 12
# Nepal!$!NP                              12
# Africa!$!3A                             11
# Republic of Mozambique!$!MZ             11
# Name: country_namecode, dtype: int64

# %%
#10 top project names/sectors

import pandas as pd
import json
from pandas.io.json import json_normalize

data= json.load((open('C:/Users/Owner/Documents/data_science/1574117884_data_wrangling_json_5_/data_wrangling_json/data/World_Bank_projects.json')))
normalized_data = json_normalize(data, record_path='mjtheme_namecode')
df = pd.DataFrame(normalized_data)
df_sorted = df['name'].value_counts()
print(df_sorted.head(10))
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Name: name, dtype: int64

# %%
# All projects names that were missing have been filled using project codes

import numpy as np

data= json.load((open('C:/Users/Owner/Documents/data_science/1574117884_data_wrangling_json_5_/data_wrangling_json/data/World_Bank_projects.json')))
normalized_data = json_normalize(data, record_path='mjtheme_namecode')
df = pd.DataFrame(normalized_data)
new_df = (df.replace({'name':{'':np.nan}})
          .sort_values(['code', 'name'])
          .fillna(method='ffill')
          .sort_index())
print(new_df)
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11  Environment and natural resources management
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6         Social protection and risk management
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...
